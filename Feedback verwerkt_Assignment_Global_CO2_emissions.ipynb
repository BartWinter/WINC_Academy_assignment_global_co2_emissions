# %%
import pandas as pd
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_carbon_dioxide_emissions')
countries = tables[1]
countries
# Out:
#                         Country[20] Fossil CO2 emissions(Mt CO2)             \
#                         Country[20]                         1990       2005
# 0                             World                    22674.116  30049.809
# 1    World – International Aviation                      258.941    422.777
# 2    World – International Shipping                      371.804    572.169
# 3                       Afghanistan                        2.546      1.063
# 4                           Albania                        6.583      4.196
# ..                              ...                          ...        ...
# 207                         Vietnam                       20.182     99.231
# 208                  Western Sahara                        0.144      0.227
# 209                           Yemen                        6.887     21.768
# 210                          Zambia                        2.955      2.457
# 211                        Zimbabwe                       17.178     11.388
#
#                Fossil CO2 emissions                           \
#           2017     2017(% of world) 2017 vs 1990: change (%)
# 0    37077.404              100.00%                    63.5%
# 1      543.381                1.47%                   109.8%
# 2      677.248                1.83%                    82.2%
# 3       11.422                0.03%                   348.6%
# 4        5.026                0.01%                   -23.7%
# ..         ...                  ...                      ...
# 207    218.729                0.59%                   983.8%
# 208      0.276                0.00%                    91.7%
# 209     12.503                0.03%                    81.5%
# 210      4.967                0.01%                    68.1%
# 211     12.087                0.03%                   -29.6%
#
#     2017 – Fossil CO2 emissions                           \
#     Per land area(t CO2/km2/yr) Per capita(t CO2/cap/yr)
# 0                          73.0                      4.9
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                          18.0                      0.3
# 4                         175.0                      1.7
# ..                          ...                      ...
# 207                       660.0                      2.3
# 208                         1.0                      0.5
# 209                        24.0                      0.4
# 210                         7.0                      0.3
# 211                        31.0                      0.7
#
#       2018 CO2 emissions[21]
#     Total including LUCF[22] Total excluding LUCF[23]
# 0                   36431.11                 35247.21
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                       7.59                     7.44
# 4                       5.32                     5.56
# ..                       ...                      ...
# 207                   245.36                   257.86
# 208                      NaN                      NaN
# 209                     9.31                     9.31
# 210                    40.47                     7.74
# 211                    99.43                    12.27
#
# [212 rows x 10 columns]

# %%
#Convert it into a non-Multilndex dataframe
countries.columns = ['country', 'co2_1990', 'co2_2005', 'co2_2017', '2017(% of world)', '2017 vs 1990: change (%)', 'per land area', 'per capita', 'total including lucf', 'total excluding lucf']
countries
# Out:
#                             country   co2_1990   co2_2005   co2_2017  \
# 0                             World  22674.116  30049.809  37077.404
# 1    World – International Aviation    258.941    422.777    543.381
# 2    World – International Shipping    371.804    572.169    677.248
# 3                       Afghanistan      2.546      1.063     11.422
# 4                           Albania      6.583      4.196      5.026
# ..                              ...        ...        ...        ...
# 207                         Vietnam     20.182     99.231    218.729
# 208                  Western Sahara      0.144      0.227      0.276
# 209                           Yemen      6.887     21.768     12.503
# 210                          Zambia      2.955      2.457      4.967
# 211                        Zimbabwe     17.178     11.388     12.087
#
#     2017(% of world) 2017 vs 1990: change (%)  per land area  per capita  \
# 0            100.00%                    63.5%           73.0         4.9
# 1              1.47%                   109.8%            NaN         NaN
# 2              1.83%                    82.2%            NaN         NaN
# 3              0.03%                   348.6%           18.0         0.3
# 4              0.01%                   -23.7%          175.0         1.7
# ..               ...                      ...            ...         ...
# 207            0.59%                   983.8%          660.0         2.3
# 208            0.00%                    91.7%            1.0         0.5
# 209            0.03%                    81.5%           24.0         0.4
# 210            0.01%                    68.1%            7.0         0.3
# 211            0.03%                   -29.6%           31.0         0.7
#
#     total including lucf total excluding lucf
# 0               36431.11             35247.21
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                   7.59                 7.44
# 4                   5.32                 5.56
# ..                   ...                  ...
# 207               245.36               257.86
# 208                  NaN                  NaN
# 209                 9.31                 9.31
# 210                40.47                 7.74
# 211                99.43                12.27
#
# [212 rows x 10 columns]

# %%
#Filter out the rows in this table that aren't countries 

#countries = countries.loc[3:]

countries = countries[countries['country'].str.contains("World|European") == False]
countries
# Out:
#             country  co2_1990  co2_2005  co2_2017 2017(% of world)  \
# 3       Afghanistan     2.546     1.063    11.422            0.03%
# 4           Albania     6.583     4.196     5.026            0.01%
# 5           Algeria    65.677    98.197   159.929            0.43%
# 6            Angola     5.851    15.975    30.876            0.08%
# 7          Anguilla     0.006     0.014     0.028            0.00%
# ..              ...       ...       ...       ...              ...
# 207         Vietnam    20.182    99.231   218.729            0.59%
# 208  Western Sahara     0.144     0.227     0.276            0.00%
# 209           Yemen     6.887    21.768    12.503            0.03%
# 210          Zambia     2.955     2.457     4.967            0.01%
# 211        Zimbabwe    17.178    11.388    12.087            0.03%
#
#     2017 vs 1990: change (%)  per land area  per capita total including lucf  \
# 3                     348.6%           18.0         0.3                 7.59
# 4                     -23.7%          175.0         1.7                 5.32
# 5                     143.5%           67.0         3.9               151.87
# 6                     427.7%           25.0         1.0                62.93
# 7                     366.7%          308.0         1.9                  NaN
# ..                       ...            ...         ...                  ...
# 207                   983.8%          660.0         2.3               245.36
# 208                    91.7%            1.0         0.5                  NaN
# 209                    81.5%           24.0         0.4                 9.31
# 210                    68.1%            7.0         0.3                40.47
# 211                   -29.6%           31.0         0.7                99.43
#
#     total excluding lucf
# 3                   7.44
# 4                   5.56
# 5                 151.67
# 6                  27.34
# 7                    NaN
# ..                   ...
# 207               257.86
# 208                  NaN
# 209                 9.31
# 210                 7.74
# 211                12.27
#
# [208 rows x 10 columns]

# %%
#Top 5 biggest CO2 producers based on the latest measurement
sorted_countries_2017 = countries.sort_values(by=['co2_2017'], ascending = False)
sorted_countries_2017
# Out:
#                                           country  co2_1990  co2_2005  \
# 42                                          China  2397.048  6263.064
# 202                                 United States  5085.897  5971.571
# 93                                          India   605.968  1210.754
# 158                                        Russia  2378.921  1733.950
# 102                                         Japan  1149.400  1276.863
# ..                                            ...       ...       ...
# 68                               Falkland Islands     0.013     0.016
# 106                                      Kiribati     0.020     0.033
# 7                                        Anguilla     0.006     0.014
# 160  Saint Helena, Ascension and Tristan da Cunha     0.010     0.010
# 69                                  Faroe Islands     0.001     0.002
#
#       co2_2017 2017(% of world) 2017 vs 1990: change (%)  per land area  \
# 42   10877.218           29.34%                   353.8%         1133.0
# 202   5107.393           13.77%                     0.4%          519.0
# 93    2454.774            6.62%                   305.1%          747.0
# 158   1764.866            4.76%                   -25.8%          103.0
# 102   1320.776            3.56%                    14.9%         3494.0
# ..         ...              ...                      ...            ...
# 68       0.038            0.00%                   192.3%            3.0
# 106      0.030            0.00%                    50.0%           37.0
# 7        0.028            0.00%                   366.7%          308.0
# 160      0.015            0.00%                    50.0%           49.0
# 69       0.002            0.00%                   100.0%            1.0
#
#      per capita total including lucf total excluding lucf
# 42          7.7              9663.36             10313.46
# 202        15.7              4749.57              4981.30
# 93          1.8              2400.25              2434.52
# 158        12.3              1049.05              1607.55
# 102        10.4              1074.08              1106.15
# ..          ...                  ...                  ...
# 68         13.1                  NaN                  NaN
# 106         0.3                 0.08                 0.08
# 7           1.9                  NaN                  NaN
# 160         3.7                  NaN                  NaN
# 69         23.1                  NaN                  NaN
#
# [208 rows x 10 columns]

# %% [markdown]
# **Graph 1: CO2 of the bigger countries**

# %%
import matplotlib.pyplot as plt
import numpy as np

#top5 = sorted_countries_2017.loc([42, 202, 67, 93, 158], [country, 1990, 2005, 2017])
top5 = sorted_countries_2017.iloc[0:5, 0:4] 

fix, ax = plt.subplots()
years = ["1990", "2005", "2017"]

for index, row in top5.iterrows():
  plt.plot(years, row[1:], label = row[0])
ax.set_title("The 5 biggest CO2 producers in the world", fontweight = "bold")
ax.set_xlabel("Year")
ax.set_ylabel("CO2 emission in Mt")
ax.legend(bbox_to_anchor=(1, 0.5) )
ax.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **Graph 2: worst and best changers**

# %%
#Calculate the relative change in CO2 emission and adding new columns to the dataframe
countries["rel_1990"] = 100
countries["rel_2005"] = ((countries.loc[:,"co2_2005"]/countries.loc[:,"co2_1990"])*100)
countries["rel_2017"] = ((countries.loc[:,"co2_2017"]/countries.loc[:,"co2_1990"])*100)
countries
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#             country  co2_1990  co2_2005  co2_2017 2017(% of world)  \
# 3       Afghanistan     2.546     1.063    11.422            0.03%
# 4           Albania     6.583     4.196     5.026            0.01%
# 5           Algeria    65.677    98.197   159.929            0.43%
# 6            Angola     5.851    15.975    30.876            0.08%
# 7          Anguilla     0.006     0.014     0.028            0.00%
# ..              ...       ...       ...       ...              ...
# 207         Vietnam    20.182    99.231   218.729            0.59%
# 208  Western Sahara     0.144     0.227     0.276            0.00%
# 209           Yemen     6.887    21.768    12.503            0.03%
# 210          Zambia     2.955     2.457     4.967            0.01%
# 211        Zimbabwe    17.178    11.388    12.087            0.03%
#
#     2017 vs 1990: change (%)  per land area  per capita total including lucf  \
# 3                     348.6%           18.0         0.3                 7.59
# 4                     -23.7%          175.0         1.7                 5.32
# 5                     143.5%           67.0         3.9               151.87
# 6                     427.7%           25.0         1.0                62.93
# 7                     366.7%          308.0         1.9                  NaN
# ..                       ...            ...         ...                  ...
# 207                   983.8%          660.0         2.3               245.36
# 208                    91.7%            1.0         0.5                  NaN
# 209                    81.5%           24.0         0.4                 9.31
# 210                    68.1%            7.0         0.3                40.47
# 211                   -29.6%           31.0         0.7                99.43
#
#     total excluding lucf  rel_1990    rel_2005     rel_2017
# 3                   7.44       100   41.751767   448.625295
# 4                   5.56       100   63.739936    76.348170
# 5                 151.67       100  149.515051   243.508382
# 6                  27.34       100  273.030251   527.704666
# 7                    NaN       100  233.333333   466.666667
# ..                   ...       ...         ...          ...
# 207               257.86       100  491.680706  1083.782579
# 208                  NaN       100  157.638889   191.666667
# 209                 9.31       100  316.073762   181.544940
# 210                 7.74       100   83.147208   168.087986
# 211                12.27       100   66.294097    70.363255
#
# [208 rows x 13 columns]

# %%
#Sort values by rel_2017
sorted_countries_rel_2017 = countries.sort_values(by=["rel_2017"], ascending = False)
sorted_countries_rel_2017
# Out:
#                       country  co2_1990  co2_2005  co2_2017 2017(% of world)  \
# 81                  Greenland     0.003     0.631     0.518            0.00%
# 34                   Cambodia     0.407     2.686    10.560            0.03%
# 62          Equatorial Guinea     0.097     3.371     2.469            0.01%
# 197  Turks and Caicos Islands     0.007     0.005     0.165            0.00%
# 37                 Cape Verde     0.049     0.227     0.955            0.00%
# ..                        ...       ...       ...       ...              ...
# 76                    Georgia    34.745     4.979    11.558            0.03%
# 141               North Korea   131.365    79.568    37.774            0.10%
# 199                   Ukraine   783.210   354.429   205.723            0.55%
# 128                   Moldova    31.957     8.139     8.263            0.02%
# 10                    Armenia    20.699     4.542     4.832            0.01%
#
#     2017 vs 1990: change (%)  per land area  per capita total including lucf  \
# 81                 17,166.7%            0.0         9.2                  NaN
# 34                  2,494.6%           58.0         0.7                40.16
# 62                  2,445.4%           88.0         1.9                10.51
# 197                 2,257.1%          174.0         4.7                  NaN
# 37                  1,849.0%          237.0         1.7                 0.56
# ..                       ...            ...         ...                  ...
# 76                    -66.7%          166.0         3.0                 9.46
# 141                   -71.2%          313.0         1.5                21.41
# 199                   -73.7%          341.0         4.7               173.18
# 128                   -74.1%          244.0         2.0                 8.70
# 10                    -76.7%          162.0         1.6                 5.59
#
#     total excluding lucf  rel_1990      rel_2005      rel_2017
# 81                   NaN       100  21033.333333  17266.666667
# 34                 11.16       100    659.950860   2594.594595
# 62                  6.67       100   3475.257732   2545.360825
# 197                  NaN       100     71.428571   2357.142857
# 37                  0.62       100    463.265306   1948.979592
# ..                   ...       ...           ...           ...
# 76                  9.46       100     14.330119     33.265218
# 141                18.12       100     60.570167     28.754996
# 199               185.37       100     45.253380     26.266646
# 128                 8.59       100     25.468598     25.856620
# 10                  5.55       100     21.943089     23.344123
#
# [208 rows x 13 columns]

# %%
#Find the top three and bottom three countries with regards to lowering these emissions
sorted_countries_rel_2017 = sorted_countries_rel_2017.head(3).append(sorted_countries_rel_2017.tail(3))
sorted_countries_rel_2017
# Out:
#                country  co2_1990  co2_2005  co2_2017 2017(% of world)  \
# 81           Greenland     0.003     0.631     0.518            0.00%
# 34            Cambodia     0.407     2.686    10.560            0.03%
# 62   Equatorial Guinea     0.097     3.371     2.469            0.01%
# 199            Ukraine   783.210   354.429   205.723            0.55%
# 128            Moldova    31.957     8.139     8.263            0.02%
# 10             Armenia    20.699     4.542     4.832            0.01%
#
#     2017 vs 1990: change (%)  per land area  per capita total including lucf  \
# 81                 17,166.7%            0.0         9.2                  NaN
# 34                  2,494.6%           58.0         0.7                40.16
# 62                  2,445.4%           88.0         1.9                10.51
# 199                   -73.7%          341.0         4.7               173.18
# 128                   -74.1%          244.0         2.0                 8.70
# 10                    -76.7%          162.0         1.6                 5.59
#
#     total excluding lucf  rel_1990      rel_2005      rel_2017
# 81                   NaN       100  21033.333333  17266.666667
# 34                 11.16       100    659.950860   2594.594595
# 62                  6.67       100   3475.257732   2545.360825
# 199               185.37       100     45.253380     26.266646
# 128                 8.59       100     25.468598     25.856620
# 10                  5.55       100     21.943089     23.344123

# %%
#Select the right rows and columns voor the line chart

top_and_bottom_3 = sorted_countries_rel_2017.iloc[:,[0,10,11,12]]
top_and_bottom_3
# Out:
#                country  rel_1990      rel_2005      rel_2017
# 81           Greenland       100  21033.333333  17266.666667
# 34            Cambodia       100    659.950860   2594.594595
# 62   Equatorial Guinea       100   3475.257732   2545.360825
# 199            Ukraine       100     45.253380     26.266646
# 128            Moldova       100     25.468598     25.856620
# 10             Armenia       100     21.943089     23.344123

# %%
#Plot the line chart

fig, ax = plt.subplots()

years = ["1990", "2005", "2017"]

for index, row in top_and_bottom_3.iterrows():
  plt.plot(years, row[1:], label = row[0])

ax.set_ylim((-10000,25000))
ax.set_title("Worst and best CO2 changers", fontweight = "bold")
ax.set_xlabel("Year")
ax.set_ylabel("Relative CO2 emission in Mt, compared to 1990")
ax.legend(bbox_to_anchor=(1, 0.5))
ax.grid(True)
ax.minorticks_on()
fig.set_size_inches(8,6)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Create a more useful chart: the same chart for all countries that had a least five MT of CO2 emissions in 1990

co2_1990_high = countries.loc[(countries.co2_1990 > 5)]
co2_1990_high
# Out:
#         country  co2_1990  co2_2005  co2_2017 2017(% of world)  \
# 4       Albania     6.583     4.196     5.026            0.01%
# 5       Algeria    65.677    98.197   159.929            0.43%
# 6        Angola     5.851    15.975    30.876            0.08%
# 9     Argentina   112.434   165.429   209.968            0.57%
# 10      Armenia    20.699     4.542     4.832            0.01%
# ..          ...       ...       ...       ...              ...
# 204  Uzbekistan   123.106   116.386    95.350            0.26%
# 206   Venezuela   109.268   152.464   145.877            0.39%
# 207     Vietnam    20.182    99.231   218.729            0.59%
# 209       Yemen     6.887    21.768    12.503            0.03%
# 211    Zimbabwe    17.178    11.388    12.087            0.03%
#
#     2017 vs 1990: change (%)  per land area  per capita total including lucf  \
# 4                     -23.7%          175.0         1.7                 5.32
# 5                     143.5%           67.0         3.9               151.87
# 6                     427.7%           25.0         1.0                62.93
# 9                      86.7%           76.0         4.7               207.11
# 10                    -76.7%          162.0         1.6                 5.59
# ..                       ...            ...         ...                  ...
# 204                   -22.5%          213.0         3.0               108.72
# 206                    33.5%          159.0         4.6               181.29
# 207                   983.8%          660.0         2.3               245.36
# 209                    81.5%           24.0         0.4                 9.31
# 211                   -29.6%           31.0         0.7                99.43
#
#     total excluding lucf  rel_1990    rel_2005     rel_2017
# 4                   5.56       100   63.739936    76.348170
# 5                 151.67       100  149.515051   243.508382
# 6                  27.34       100  273.030251   527.704666
# 9                 177.41       100  147.134319   186.747781
# 10                  5.55       100   21.943089    23.344123
# ..                   ...       ...         ...          ...
# 204               112.09       100   94.541290    77.453577
# 206               138.16       100  139.532159   133.503862
# 207               257.86       100  491.680706  1083.782579
# 209                 9.31       100  316.073762   181.544940
# 211                12.27       100   66.294097    70.363255
#
# [104 rows x 13 columns]

# %%
#Sort values by rel_2017
sorted_countries_rel_2017_new = co2_1990_high.sort_values(by=["rel_2017"], ascending = False)
sorted_countries_rel_2017_new
# Out:
#          country  co2_1990  co2_2005  co2_2017 2017(% of world)  \
# 207      Vietnam    20.182    99.231   218.729            0.59%
# 144         Oman    11.884    32.964    78.421            0.21%
# 17    Bangladesh    13.868    38.834    84.546            0.23%
# 155        Qatar    16.291    43.435    97.787            0.26%
# 6         Angola     5.851    15.975    30.876            0.08%
# ..           ...       ...       ...       ...              ...
# 76       Georgia    34.745     4.979    11.558            0.03%
# 141  North Korea   131.365    79.568    37.774            0.10%
# 199      Ukraine   783.210   354.429   205.723            0.55%
# 128      Moldova    31.957     8.139     8.263            0.02%
# 10       Armenia    20.699     4.542     4.832            0.01%
#
#     2017 vs 1990: change (%)  per land area  per capita total including lucf  \
# 207                   983.8%          660.0         2.3               245.36
# 144                   559.9%          253.0        16.9                73.39
# 17                    509.6%          573.0         0.5               104.50
# 155                   500.3%         8440.0        37.1                90.17
# 6                     427.7%           25.0         1.0                62.93
# ..                       ...            ...         ...                  ...
# 76                    -66.7%          166.0         3.0                 9.46
# 141                   -71.2%          313.0         1.5                21.41
# 199                   -73.7%          341.0         4.7               173.18
# 128                   -74.1%          244.0         2.0                 8.70
# 10                    -76.7%          162.0         1.6                 5.59
#
#     total excluding lucf  rel_1990    rel_2005     rel_2017
# 207               257.86       100  491.680706  1083.782579
# 144                73.37       100  277.381353   659.887243
# 17                 82.76       100  280.025959   609.648111
# 155                90.17       100  266.619606   600.251673
# 6                  27.34       100  273.030251   527.704666
# ..                   ...       ...         ...          ...
# 76                  9.46       100   14.330119    33.265218
# 141                18.12       100   60.570167    28.754996
# 199               185.37       100   45.253380    26.266646
# 128                 8.59       100   25.468598    25.856620
# 10                  5.55       100   21.943089    23.344123
#
# [104 rows x 13 columns]

# %%
#Find the top three and bottom three countries with regards to lowering these emissions
sorted_countries_rel_2017_new = sorted_countries_rel_2017_new.head(3).append(sorted_countries_rel_2017_new.tail(3))
sorted_countries_rel_2017_new
# Out:
#         country  co2_1990  co2_2005  co2_2017 2017(% of world)  \
# 207     Vietnam    20.182    99.231   218.729            0.59%
# 144        Oman    11.884    32.964    78.421            0.21%
# 17   Bangladesh    13.868    38.834    84.546            0.23%
# 199     Ukraine   783.210   354.429   205.723            0.55%
# 128     Moldova    31.957     8.139     8.263            0.02%
# 10      Armenia    20.699     4.542     4.832            0.01%
#
#     2017 vs 1990: change (%)  per land area  per capita total including lucf  \
# 207                   983.8%          660.0         2.3               245.36
# 144                   559.9%          253.0        16.9                73.39
# 17                    509.6%          573.0         0.5               104.50
# 199                   -73.7%          341.0         4.7               173.18
# 128                   -74.1%          244.0         2.0                 8.70
# 10                    -76.7%          162.0         1.6                 5.59
#
#     total excluding lucf  rel_1990    rel_2005     rel_2017
# 207               257.86       100  491.680706  1083.782579
# 144                73.37       100  277.381353   659.887243
# 17                 82.76       100  280.025959   609.648111
# 199               185.37       100   45.253380    26.266646
# 128                 8.59       100   25.468598    25.856620
# 10                  5.55       100   21.943089    23.344123

# %%
#Select the right rows and columns voor the line chart

top_and_bottom_3_new = sorted_countries_rel_2017_new.iloc[[0,1,2,3,4,5],[0,10,11,12]]
top_and_bottom_3_new
# Out:
#         country  rel_1990    rel_2005     rel_2017
# 207     Vietnam       100  491.680706  1083.782579
# 144        Oman       100  277.381353   659.887243
# 17   Bangladesh       100  280.025959   609.648111
# 199     Ukraine       100   45.253380    26.266646
# 128     Moldova       100   25.468598    25.856620
# 10      Armenia       100   21.943089    23.344123

# %%
#Plot the line chart

fig, ax = plt.subplots()

years = ["1990", "2005", "2017"]

for index, row in top_and_bottom_3_new.iterrows():
  plt.plot(years, row[1:], label = row[0])

ax.set_ylim((-100,1500))
ax.set_title("Worst and best CO2 changers (min CO2 emission in 1990 = 5 Mt)", fontweight = "bold")
ax.set_xlabel("Year")
ax.set_ylabel("Relative CO2 emission in Mt, compared to 1990")
ax.legend(bbox_to_anchor=(1, 0.5))
ax.grid(True)
ax.minorticks_on()
fig.set_size_inches(8,6)
plt.show
# Out:
# <function matplotlib.pyplot.show>
